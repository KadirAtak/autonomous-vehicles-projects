# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/Datasets/TrafficSign/car/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="car_detector"
)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 109MB/s]
# Ultralytics 8.3.136 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
log_path = "/content/runs/detect/car_detector2/results.csv"
df = pd.read_csv(log_path)

print("Sütunlar:")
print(df.columns.tolist())
# Out:
# Sütunlar:
# ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']

# %%
import matplotlib.pyplot as plt

epochs = df['epoch'] + 1

plt.figure(figsize=(10, 5))
plt.plot(epochs, df['train/box_loss'], label='Box Loss')
plt.plot(epochs, df['train/cls_loss'], label='Class Loss')
plt.plot(epochs, df['train/dfl_loss'], label='DFL Loss')
plt.title("YOLOv8 Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
final_row = df.iloc[-1]

precision = final_row['metrics/precision(B)']
recall = final_row['metrics/recall(B)']
map_50 = final_row['metrics/mAP50(B)']
map_50_95 = final_row['metrics/mAP50-95(B)']

print(f"🎯 Model Başarı Özeti (Son Epoch):")
print(f"- Precision: %{precision * 100:.2f}")
print(f"- Recall: %{recall * 100:.2f}")
print(f"- mAP@0.5: %{map_50 * 100:.2f}")
print(f"- mAP@0.5:0.95: %{map_50_95 * 100:.2f}")
# Out:
# 🎯 Model Başarı Özeti (Son Epoch):
# - Precision: %95.49
# - Recall: %92.30
# - mAP@0.5: %96.66
# - mAP@0.5:0.95: %84.09

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt


model = YOLO("/content/runs/detect/car_detector2/weights/best.pt")


img_path = "/content/drive/MyDrive/Datasets/TrafficSign/car/test/images/00000_00000_00017_png.rf.6c2381a6a103a041f23159fbd44868ed.jpg"
results = model(img_path)

results[0].save(filename="result.jpg")

img = cv2.imread("result.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
plt.title("Tahmin Sonucu")
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/Datasets/TrafficSign/car/test/images/00000_00000_00017_png.rf.6c2381a6a103a041f23159fbd44868ed.jpg: 640x640 1 Speed Limit 20, 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !pip install ultralytics --quiet


from ultralytics import YOLO


model_path = "/content/runs/detect/car_detector2/weights/best.pt"
model = YOLO(model_path)


video_path = "/content/drive/MyDrive/Datasets/TrafficSign/video.mp4"

model.predict(
    source=video_path,
    save=True,
    save_txt=False,
    imgsz=640,
    conf=0.3,
    name="pot_video"
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/508) /content/drive/MyDrive/Datasets/TrafficSign/video.mp4: 640x640 1 Stop, 7.5ms
# video 1/1 (frame 2/508) /content/drive/MyDrive/Datasets/TrafficSign/video.mp4: 640x640 1 Stop, 7.5ms
# video 1/1 (frame 3/508) /content/drive/MyDrive/Datasets/TrafficSign/video.mp4: 640x640 1 Stop, 7.4ms
# video 1/1 (frame 4/508) /content/drive/MyDrive/Datasets/TrafficSign/video.mp4: 640x640 (no detections), 7.4ms
# ...

# %%
# !pip install ultralytics --quiet


from ultralytics import YOLO
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
import torch
import torch.nn as nn


pothole_model = YOLO("/content/drive/MyDrive/Datasets/pothole.pt")
sign_model = YOLO("/content/drive/MyDrive/Datasets/traffic.pt")

class SmallUNet(nn.Module):
    def __init__(self):
        super(SmallUNet, self).__init__()

        def CBR(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
            )

        self.enc1 = CBR(3, 32)
        self.enc2 = CBR(32, 64)
        self.enc3 = CBR(64, 128)
        self.enc4 = CBR(128, 256)
        self.enc5 = CBR(256, 512)
        self.pool = nn.MaxPool2d(2)
        self.bottleneck = CBR(512, 1024)
        self.upconv5 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec5 = CBR(1024, 512)
        self.upconv4 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec4 = CBR(512, 256)
        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec3 = CBR(256, 128)
        self.upconv2 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec2 = CBR(128, 64)
        self.upconv1 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec1 = CBR(64, 32)
        self.final = nn.Conv2d(32, 1, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        e5 = self.enc5(self.pool(e4))
        b = self.bottleneck(self.pool(e5))
        d5 = self.dec5(torch.cat((e5, self.upconv5(b)), dim=1))
        d4 = self.dec4(torch.cat((e4, self.upconv4(d5)), dim=1))
        d3 = self.dec3(torch.cat((e3, self.upconv3(d4)), dim=1))
        d2 = self.dec2(torch.cat((e2, self.upconv2(d3)), dim=1))
        d1 = self.dec1(torch.cat((e1, self.upconv1(d2)), dim=1))
        return torch.sigmoid(self.final(d1))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
unet_model = SmallUNet().to(device)
unet_model.load_state_dict(torch.load("/content/drive/MyDrive/Datasets/lanedetection.pth", map_location=device))
unet_model.eval()
# Out:
# SmallUNet(
#   (enc1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
from torchvision import transforms
import numpy as np
from google.colab.patches import cv2_imshow

transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# %%
video_path = "/content/drive/MyDrive/Datasets/Pothole Video.mp4"
cap = cv2.VideoCapture(video_path)


width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)


fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("processed_output.mp4", fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    original = frame.copy()

    lane_input = transform(cv2.cvtColor(original, cv2.COLOR_BGR2RGB)).unsqueeze(0).to(device)
    with torch.no_grad():
        lane_output = unet_model(lane_input)[0].cpu().numpy().squeeze()
        lane_mask = (lane_output > 0.5).astype(np.uint8) * 255
        lane_mask = cv2.resize(lane_mask, (width, height))
        frame[lane_mask == 255] = [0, 255, 0]


    pothole_results = pothole_model.predict(source=frame, conf=0.3, verbose=False)
    frame = pothole_results[0].plot()

    sign_results = sign_model.predict(source=frame, conf=0.3, verbose=False)
    frame = sign_results[0].plot()

    out.write(frame)

cap.release()
out.release()
print("✅ İşlem tamam! Video dosyası: processed_output.mp4")
# Out:
# ✅ İşlem tamam! Video dosyası: processed_output.mp4
